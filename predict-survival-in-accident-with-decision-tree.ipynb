# %% [markdown]
# <a href="https://www.kaggle.com/code/willyankoeswara/classify-survival-in-accident-with-decision-tree?scriptVersionId=95030925" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Dataset

# %%
import pandas as pd
df = pd.read_csv("../input/ttnccsv/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Remove Label That We Dont Need
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)

# %% [markdown]
# **Fill null with Mean**

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# dtype: int64

# %%
x = df["Age"].mean()
df["Age"].fillna(x, inplace = True)

# %%
# Convert Float to Int
df.Age = df.Age.astype(int)
df.Fare = df.Fare.astype(int)

# %%
# Convert String to Int
df['Sex'] = df['Sex'].apply({'male':1,'female':0}.get)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    int64
#  4   Fare      891 non-null    int64
# dtypes: int64(5)
# memory usage: 34.9 KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.544332   31.785634
# std      0.486592    0.836071    0.477990   13.013778   49.703730
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    7.000000
# 50%      0.000000    3.000000    1.000000   29.000000   14.000000
# 75%      1.000000    3.000000    1.000000   35.000000   31.000000
# max      1.000000    3.000000    1.000000   80.000000  512.000000

# %%
df
# Out:
#      Survived  Pclass  Sex  Age  Fare
# 0           0       3    1   22     7
# 1           1       1    0   38    71
# 2           1       3    0   26     7
# 3           1       1    0   35    53
# 4           0       3    1   35     8
# ..        ...     ...  ...  ...   ...
# 886         0       2    1   27    13
# 887         1       1    0   19    30
# 888         0       3    0   29    23
# 889         1       1    1   26    30
# 890         0       3    1   32     7
#
# [891 rows x 5 columns]

# %% [markdown]
# # Split Data

# %%
inputs = df.drop('Survived',axis='columns')
target = df['Survived']

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

model.fit(inputs, target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Score Accuration**

# %%
model.score(inputs,target)
# Out:
# 0.9494949494949495

# %% [markdown]
# **Prediction**

# %%
model.predict([[2,1,24,30]])
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array([0])

# %% [markdown]
# 0 mean not survive
#
# 1 mean survive
